# %%
from matplotlib import pyplot as plt

# %%
import pandas as pd

# %%
import numpy as np

# %%
accuracy_array_1=pd.read_csv("accuracy_array_optagan_yahoo_investigation_1.csv", index_col="Unnamed: 0")
accuracy_np_1 = accuracy_array_1['0'].to_numpy()

# %%
accuracy_array_2 = pd.read_csv("accuracy_array_optagan_yahoo_nt_rt_768_0_yiew.csv", index_col="Unnamed: 0")
accuracy_np_2 = accuracy_array_2['0'].to_numpy()

# %%
plt.figure(figsize=(8,6))
plt.plot(accuracy_np_1)
plt.plot(accuracy_np_2)
plt.title('Graphing Multiple Runs', fontsize=20)
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.xlim(0,200)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
max(accuracy_array_2['0'])
# Out:
# 0.515

# %%
def annot_max(x,y, ax=None):
    xmax = x
    ymax = y
    text= "x={:}, y={:.3f}".format(xmax, ymax)
    if not ax:
        ax=plt.gca()
    bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
    arrowprops=dict(arrowstyle="->",connectionstyle="angle,angleA=0,angleB=60")
    kw = dict(xycoords='data',textcoords="axes fraction",
              arrowprops=arrowprops, bbox=bbox_props, ha="right", va="top")
    ax.annotate(text, xy=(xmax, ymax), xytext=(0.94,0.96), fontsize=13, **kw)

# %%
ymax = max(accuracy_np_2)
xpos = np.where(accuracy_np_2==ymax)
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
plt.plot(accuracy_list_2, label="Thesis")
plt.axhline(y=0.420, color='r', linestyle='-', label="BERT Baseline")
plt.axhline(y=0.475, color='g', linestyle='-', label="GAN-BERT Baseline")
# ax.annotate('local max', xy=(xpos[0][0], ymax), xytext=(xpos[0][0], ymax+0.05),
#             arrowprops=dict(facecolor='black', shrink=1),
#             )
annot_max(xpos[0][0], ymax)
plt.title('Additional Discriminator OPTAGAN Performance', fontsize=20)
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy (%)', fontsize=16)
plt.xlim(0,200)
plt.ylim(0,0.65)
plt.legend(loc="lower right", prop={'size': 12})
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(xpos[0][0])
# Out:
# 26

# %%
print(accuracy_list_2.index(0.495))
# Out:
# /home/harry/venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: elementwise == comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-566ba5c1138b> in <module>
# ----> 1 print(accuracy_list_2.index(0.495))
#
# ValueError: 0.495 is not in list
